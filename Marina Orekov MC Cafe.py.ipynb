# %%
import pprint 
pp = pprint.PrettyPrinter(indent=4)


print("Welcome to MC Cafe!")

boolmenu = input("Would you like to see the menu?(Y/N)")

if boolmenu == "Y":
    
    pp.pprint(menu)  
    


Coffee = {"Espresso": 1.50, "Americano": 2.00, "Caffe latte" : 2.25, "Mocha":2.25, "Cappucino":2.50,"Macchiato":2.50}
Tea = {"White tea":1.50, "Green tea":2.00,"Oolong tea":2.25,"Black tea":2.25,"Earl Grey":2.50,"Matcha":2.50}
Pastries = {"Croissant":5.50, "Cinnamon roll":4.50,"Banana bread":4.25,"Pumpkin bread":3.75,"Sticky bun":4.25,"Apple turnover":3.75}

#print(Tea["White tea"])
menu = {
  "Coffee" : Coffee,
  "Tea" : Tea,
  "Pastries" : Pastries
}
price = {"Espresso": 1.50, "Americano": 2.00, "Caffe latte" : 2.25, "Mocha":2.25, "Cappucino":2.50,"Macchiato":2.50,"White tea":1.50, "Green tea":2.00,"Oolong tea":2.25,"Black tea":2.25,"Earl Grey":2.50,"Matcha":2.50,"Croissant":5.50, "Cinnamon roll":4.50,"Banana bread":4.25,"Pumpkin bread":3.75,"Sticky bun":4.25,"Apple turnover":3.75}
#print(items.keys())

#print(menu["Coffee"]["Espresso"]) #access the price element of a particular item

#print entire nested dictionary
def tax(s):
    tax = s * .06
    total = s + tax
    print("Your total is:")
    print("$% .2f" %total)
    #print(total)
    
#print(menu)
def bill(o): #calculate bill
    print("Calculating bill...")
    #subtotal = item X quantity,
    #build a third dictionary of items ordered and their costs
    subtotal = 0
    for item,key in o.items():
        #get the price of the item
        try:
            key = int(key)
            cost = price[item]
            quantity = key
            newcost = cost * quantity
            subtotal += newcost
        except:
            print("can't price {item}")
    #print(subtotal)
    print("Your subtotal is:")
    print("$% .2f" %subtotal)
    tax(subtotal)
        
        
val = input("Would you like to order? (Y/N):")
if val == "Y":
    play = True;
    order = {}
    
    while(play):
        try:
            item = input("What would you like?")
            item = item.capitalize()
            print(item)
            num = input("How many?")
            order[item] = num
            more = input("Would you like to order more? (Y/N):")
        

            if more == "N":
                play = False
                print("You ordered:")
                pp.pprint(order)
                #here call a method to calculated the bill
                bill(order)
        except:
            print(f"We don't have that:{item}")
#place those key values into a dictionary


print("Thank you for visiting MC Cafe!")
# Out:
# Welcome to MC Cafe!
# Would you like to see the menu?(Y/N)N
# Would you like to order? (Y/N):Y
# What would you like?white tea
# White tea
# How many?3
# Would you like to order more? (Y/N):N
# You ordered:
# {'White tea': '3'}
# Calculating bill...
# Your subtotal is:
# $ 4.50
# Your total is:
# $ 4.77
# Thank you for visiting MC Cafe!
